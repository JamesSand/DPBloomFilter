# %%
import matplotlib.pyplot as plt
import os

# 创建一些示例数据
x = [0, 1, 2, 3, 4, 5, 10, 15, 20]
# y = [0, 1, 4, 9, 16, 17]
title = "log2(m)=20, n=1e5, k=7 (Inside Query)"
line_y = 0.0
y = [
99.28,
88.83,
58.802,
28.72,
11.84,
4.565,
0.02,
0.0,
0.0,
]

# 绘制折线图
plt.figure(figsize=(8, 6))
plt.plot(x, y, marker='o', label="DP Bloom")  # 'marker='o'' 表示在每个数据点处放置一个圆圈标记
plt.title(title)  # 图表的标题
plt.xlabel('eps_0')  # X 轴的标签
plt.ylabel('Error rate')  # Y 轴的标签
plt.grid(True)  # 显示网格
plt.axhline(y=line_y, color='r', linestyle='--', label="No DP Bloom")
plt.legend()
# plt.show()  # 显示图表

plt.savefig(os.path.join("figs", f"{title}.png"))
